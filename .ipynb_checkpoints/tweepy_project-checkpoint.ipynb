# %%
import tweepy

def authentication():
    f = open("password.txt", "r")
    fl=[]
    for x in f:
        fl.append(x.rstrip())
    consumer_token=fl[0]
    consumer_secret=fl[1]
    access_token=fl[2]
    access_secret=fl[3]
    auth = tweepy.OAuthHandler(consumer_token, consumer_secret)
    auth.set_access_token(access_token,access_secret)

    api = tweepy.API(auth)
    return api
    #return 0

def search_tweet(search:str,max_num,api):
    
    public_tweet=api.search(search,count=max_num)
    print("total tweets gleaned: ",len(public_tweet))
    for tweet in public_tweet:
        print(tweet.text)
        print("\n")
    
def post_tweet(tweet,api):
    api.update_status(tweet)
api=authentication()
search_tweet("bangladesh",30,api)
#post_tweet(input("enter your tweet : "),api)
# Out:
# total tweets gleaned:  30
# ঘরের ভিতরে বটের ছায়ায় @ Bangladesh Shilpakala Academy https://t.co/UW1shnYOuL
#
#
# RT @IndiaSpend: Per capita, the UK reports one of the highest rates of acid attacks in the world; Bangladesh, India, Pakistan, Nepal, Cambo…
#
#
# RT @AskAnshul: Pakistan’s ISI is training 40 Rohingyas in Bangladesh against India.
#
# Remember Terrorist Chotta Burmi? He was a Rohingya &amp; k…
#
#
# RT @nibraz88cricket: Chris Gayle - Pakistan is one of the safest places right now in the world. You will get presidential security so you a…
#
#
# @AASAPSwedish @kungatungan @BarbEUfel Nu ändrade du kanske frågeställningen lite eller? Du menar nutid? Bangladesh?… https://t.co/L6Nr4vFKfi
#
#
# New advanced, Anti-Cut Fence to be installed at India-Bangladesh border https://t.co/sUJas89evN https://t.co/hzWmc7razv
#
#
# RT @AskAnshul: Pakistan’s ISI is training 40 Rohingyas in Bangladesh against India.
#
# Remember Terrorist Chotta Burmi? He was a Rohingya &amp; k…
#
#
# @7twxN Ochalá bangladesh 🐻 kkkk
#
#
# @Shaguftahussein @googlenews Every society experience churning at every stage may it be Bangladesh or India.Both ar… https://t.co/gkRBvLoSE5
#
#
# @shujakh98502366 @zoo_bear @err_fun @bandisanjay_bjp Wohi to rajiv gandhi ka nrc koi nahi laga raha india me. Sirf… https://t.co/EjWxMGkwG7
#
#
# RT @coolfunnytshirt: Teams like Sri Lanka and Bangladesh should first play against India B team and India C team before playing against our…
#
#
# RT @theworldindex: Estimated years of life expectancy lost due current air pollution levels
#
# 🇧🇩Bangladesh: 1.87
# 🇪🇬Egypt: 1.85
# 🇳🇪Niger: 1.80…
#
#
